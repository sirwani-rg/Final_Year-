# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib %inline

# %%
#df1=pd.read_excel('WEO_Data.xls')
df2=pd.read_csv('/content/india-economic-growth-rate.csv', error_bad_lines=False)
df3=pd.read_csv('/content/india-trade-gdp-ratio.csv', error_bad_lines=False)
df4=pd.read_csv('/content/india-literacy-rate.csv', error_bad_lines=False)
df5=pd.read_csv('/content/india-population-2021-01-27(3).csv', error_bad_lines=False)
df6=pd.read_csv('/content/india_birthrate.csv', error_bad_lines=False)
df7=pd.read_csv('/content/india_deathrate.csv', error_bad_lines=False)
df8=pd.read_csv('/content/india-exports.csv', error_bad_lines=False)
df9=pd.read_csv('/content/india-imports.csv', error_bad_lines=False)
df10=pd.read_csv('/content/india-tourism-statistics.csv', error_bad_lines=False)
df11=pd.read_csv('/content/india-unemployment-rate.csv', error_bad_lines=False)
df12=pd.read_csv('/content/india_life_expectency.csv', error_bad_lines=False)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  60 non-null     object
#  1   GDP Billions of US $  60 non-null     float64
#  2   Per Capita US $       60 non-null     float64
#  3   Annual_Change         59 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 2.0+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              60 non-null     object
#  1   Trade (% of GDP)  60 non-null     float64
#  2   Annual_Change     59 non-null     float64
#  3                     0 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 2.0+ KB

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           6 non-null      object
#  1   Literacy_Rate  6 non-null      float64
#  2   Annual_Change  5 non-null      float64
#  3                  0 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 320.0+ bytes

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           151 non-null    object
#  1   Population     151 non-null    int64
#  2   Annual_Change  150 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.7+ KB

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   date                    151 non-null    object
#  1   Births per 1000 People  151 non-null    float64
#  2   Annual_Change           150 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.7+ KB

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         151 non-null    object
#  1   Deaths per 1000 Live Births  151 non-null    float64
#  2   Annual % Change              150 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.7+ KB

# %%
df8.info()
#df8.drop(['Annual_Change'],axis=1,inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      60 non-null     object
#  1   Exports Billions of US $  60 non-null     float64
#  2   % of GDP                  60 non-null     float64
#  3   Change                    59 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 2.0+ KB

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      60 non-null     object
#  1   Imports Billions of US $  60 non-null     float64
#  2    % of GDP                 60 non-null     float64
#  3   Change                    59 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 2.0+ KB

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           24 non-null     object
#  1    Spending ($)  24 non-null     int64
#  2    % of Exports  24 non-null     float64
#  3   Unnamed: 3     2 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 896.0+ bytes

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   29 non-null     object
#  1   Unemployment Rate (%)  29 non-null     float64
#  2   Annual Change          28 non-null     float64
#  3   Unnamed: 3             2 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 1.0+ KB

# %%
df1=df8
df1.head()
# Out:
#          date  Exports Billions of US $  % of GDP  Change
# 0  1960-12-31                  1.652702    4.4632     NaN
# 1  1961-12-31                  1.688402    4.3036 -0.1859
# 2  1962-12-31                  1.757702    4.1690 -0.5798
# 3  1963-12-31                  2.072702    4.2805  8.4041
# 4  1964-12-31                  2.104202    3.7256 -6.5120

# %%
df7.info()
df7.drop(['Annual % Change'],inplace=True,axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         151 non-null    object
#  1   Deaths per 1000 Live Births  151 non-null    float64
#  2   Annual % Change              150 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 3.7+ KB

# %%
df7.set_index(['date'],inplace=True)
df2.set_index(['date'],inplace=True)

# %%
#df9.join(df7,on='date',how='left').copy()

# %%
df9.drop(['Change'],axis=1,inplace=True)

# %%
#df2['date']=df2.date.astype(object)
df3.set_index(['date'],inplace=True)
df4.set_index(['date'],inplace=True)
df5.set_index(['date'],inplace=True)
df6.set_index(['date'],inplace=True)
df9.set_index(['date'],inplace=True)
df10.set_index(['date'],inplace=True)
df11.set_index(['date'],inplace=True)
df12.set_index(['date'],inplace=True)

#df9.join(df8,on='date',how='left').copy()
#df9.join(df6,on='date',how='left').copy()
#df9.join(df5,on='date',how='left').copy()
#df9.join(df4,on='date',how='left').copy()
#df9.join([df2,df3,df4,df5,df6,df7],on=[df2['date'],df3['date'],df4['date'],df5['date'],df6['date'],df7['date']],how='left').copy()
#df9.join(df2,on='date',how='left').copy()
#pd.concat([df6['Births per 1000 People'],df5['Population'],df4['Literacy_Rate'],df3['Trade (% of GDP)'],df2['GDP Billions of US $']],join='inner')

# %%
df9.head()
# Out:
#          date  Imports Billions of US $   % of GDP
# 0  1960-12-31                  2.530503     6.8337
# 1  1961-12-31                  2.337302     5.9576
# 2  1962-12-31                  2.543103     6.0318
# 3  1963-12-31                  2.860203     5.9068
# 4  1964-12-31                  3.210903     5.6850

# %%
from functools import reduce
#dfs=[df2,df3,df5,df6,df7,df8,df9,df10,df11,df12]
#df_final = reduce(lambda left,right: pd.merge(left,right,on='date'), dfs)
dfs=[df2,df3,df5,df6,df7,df8,df9,df12]
df_final = reduce(lambda left,right: pd.merge(left,right,on='date'), dfs)

# %%
df_final.head()
# Out:
#          date  ...  Annual_Change_y
# 0  1960-12-31  ...             1.49
# 1  1961-12-31  ...             1.46
# 2  1962-12-31  ...             1.44
# 3  1963-12-31  ...             1.42
# 4  1964-12-31  ...             1.47
#
# [5 rows x 15 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                60 non-null     object
#  1   GDP Billions of US $                60 non-null     float64
#  2   Per Capita US $                     60 non-null     float64
#  3   Trade (% of GDP)                    60 non-null     float64
#  4   Population                          60 non-null     int64
#  5   Births per 1000 People              60 non-null     float64
#  6   Deaths per 1000 Live Births         60 non-null     float64
#  7   Exports Billions of US $            60 non-null     float64
#  8   % of GDP                            60 non-null     float64
#  9   Imports Billions of US $            60 non-null     float64
#  10   % of GDP                           60 non-null     float64
#  11  Life Expectancy from Birth (Years)  60 non-null     float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 6.1+ KB

# %%
df_final.drop([' '],inplace=True,axis=1)

# %%
#df_final.drop(['Unnamed: 3_x','Unnamed: 3_y','Annual_Change_y','Annual_Change_x'],axis=1,inplace=True)
df_final.drop(['Annual_Change_y','Annual_Change_x'],axis=1,inplace=True)

# %%
plt.figure(figsize=(20,15))
#ax=subplot(111)
sns.heatmap(df_final.corr(),annot=True,cmap='coolwarm',linewidths=1.0)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
df__=df_final
#X=df10.drop(['date','GDP Billions of US $','Per Capita US $','Births per 1000 People','Deaths per 1000 Live Births','Annual_Change_x','% of GDP',' % of GDP',' % of Exports','Unemployment Rate (%)'],axis=1)
X=df__.drop(['date','GDP Billions of US $','Per Capita US $','Births per 1000 People','Deaths per 1000 Live Births','% of GDP',' % of GDP'],axis=1)

Y=df_final['GDP Billions of US $']

# %%
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
df_final.to_csv('gdp_final',index=False)

# %%
#ElasticNet CV
from sklearn.linear_model import ElasticNetCV
from sklearn.metrics import mean_squared_error
alphas = [0.0001, 0.001, 0.01, 0.1, 0.3, 0.5, 0.7, 1]
elastic_cv=ElasticNetCV(alphas=alphas, cv=5)
model = elastic_cv.fit(X_train, Y_train)
ypred = model.predict(X_test)
score = model.score(X_test, Y_test)
mse = mean_squared_error(Y_test, ypred)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score, mse, np.sqrt(mse)))
# Out:
# R2:0.9792, MSE:7325.6313, RMSE:85.5899
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66109.31844903734, tolerance: 2639.7550757793524
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58550.48139247342, tolerance: 2639.7550757793524
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56445.038034921105, tolerance: 2156.188127559009
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 49719.61742352416, tolerance: 2156.188127559009
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61396.26931393857, tolerance: 2846.0693352385506
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54229.79981551905, tolerance: 2846.0693352385506
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 53169.5100491198, tolerance: 2586.0176846680884
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46154.21227300437, tolerance: 2586.0176846680884
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39160.473582510574, tolerance: 2183.2822365296565
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:472: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29892.41760546347, tolerance: 2183.2822365296565
#   tol, rng, random, positive)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62301.290400147656, tolerance: 3121.0027874273687
#   positive)

# %%
x_ax = range(len(X_test))
plt.scatter(x_ax, Y_test, s=5, color='blue', label='original')
plt.plot(x_ax, ypred, lw=0.8, color='red', label='predicted')
plt.legend()
plt.show()

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred=reg.predict(X_test)

# %%
mse = mean_squared_error(Y_test, y_pred)
score1=reg.score(X_test,Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score1, mse, np.sqrt(mse)))
# Out:
# R2:0.9782, MSE:7678.3183, RMSE:87.6260

# %%
plt.scatter(x_ax, Y_test, s=5, color='blue', label='original')
plt.plot(x_ax, y_pred, lw=0.8, color='red', label='predicted')
plt.legend()
plt.show()

# %%
#SVR

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, Y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred1 = regressor.predict(X_test)
#y_pred1 = sc.inverse_transform(y_pred1)

# %%
plt.scatter(x_ax, Y_test, s=5, color='blue', label='original')
plt.plot(x_ax, y_pred1, lw=0.8, color='red', label='predicted')
plt.legend()
plt.show()

# %%
#SGD Regressor, Bayesian Ridge, Lasso Lars, ARD Regression, Passive Aggressive Regressor, TheilSen Regressor
from sklearn.linear_model import SGDRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import LassoLars
from sklearn.linear_model import ARDRegression
from sklearn.linear_model import PassiveAggressiveRegressor
from sklearn.linear_model import TheilSenRegressor

# %%
sgd=SGDRegressor()
br=BayesianRidge()
ll=LassoLars()
ard=ARDRegression()
par=PassiveAggressiveRegressor()
tsr=TheilSenRegressor()

# %%
sgd.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1187: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning)
# SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#              eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#              learning_rate='invscaling', loss='squared_loss', max_iter=1000,
#              n_iter_no_change=5, penalty='l2', power_t=0.25, random_state=None,
#              shuffle=True, tol=0.001, validation_fraction=0.1, verbose=0,
#              warm_start=False)

# %%
br.fit(X_train, Y_train)
# Out:
# BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False)

# %%
pred_y=sgd.predict(X_test)

# %%
pred_y1=br.predict(X_test)

# %%
ll.fit(X_train, Y_train)
pred_y2=ll.predict(X_test)
ard.fit(X_train,Y_train)
pred_y3=ard.predict(X_test)
par.fit(X_train, Y_train)
pred_y4=par.predict(X_test)
tsr.fit(X_train, Y_train)
pred_y5=tsr.predict(X_test)

# %%
mse = mean_squared_error(Y_test, ypred)
score = model.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score, mse, np.sqrt(mse)))
mse1 = mean_squared_error(Y_test, y_pred)
score1 = reg.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score1, mse1, np.sqrt(mse1)))
mse2 = mean_squared_error(Y_test, pred_y)
score2 = sgd.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score2, mse2, np.sqrt(mse2)))
mse3 = mean_squared_error(Y_test, pred_y1)
score3 = br.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score3, mse3, np.sqrt(mse3)))
mse4 = mean_squared_error(Y_test, pred_y2)
score4 = ll.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score4, mse4, np.sqrt(mse4)))
mse5 = mean_squared_error(Y_test, pred_y3)
score5 = ard.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score5, mse5, np.sqrt(mse5)))
mse6 = mean_squared_error(Y_test, pred_y4)
score6 = par.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score6, mse6, np.sqrt(mse6)))
mse7 = mean_squared_error(Y_test, pred_y5)
score7 = tsr.score(X_test, Y_test)
print("R2:{0:.4f}, MSE:{1:.4f}, RMSE:{2:.4f}"
      .format(score7, mse7, np.sqrt(mse7)))
# Out:
# R2:0.9792, MSE:7325.6313, RMSE:85.5899
# R2:0.9782, MSE:7678.3183, RMSE:87.6260
# R2:0.9827, MSE:6102.1702, RMSE:78.1164
# R2:0.9801, MSE:7024.7323, RMSE:83.8137
# R2:0.9753, MSE:8706.2820, RMSE:93.3075
# R2:0.9800, MSE:7047.2825, RMSE:83.9481
# R2:0.9719, MSE:9921.1971, RMSE:99.6052
# R2:0.9872, MSE:4515.2444, RMSE:67.1956

# %%
MSE_=[mse1,mse,mse2,mse3,mse4,mse5,mse6,mse7]
R2_=[score1,score,score2,score3,score4,score5,score6,score7]
Algorithm_=['Linear Regression','ElasticNet CV','SGD Regressor','Bayesian Ridge','Lasso Lars','ARD Regression','Passive Aggressive Regressor',
'TheilSen Regressor']
acc_t=pd.DataFrame()

# %%
acc_t['ALgorithm_']=Algorithm_
acc_t['MSE_']=MSE_
acc_t['R2_']=R2_

# %%
acc_t.sort_values(by='MSE_')
# Out:
#                      ALgorithm_         MSE_       R2_
# 7            TheilSen Regressor  4515.244437  0.987200
# 2                 SGD Regressor  6102.170172  0.982701
# 3                Bayesian Ridge  7024.732273  0.980086
# 5                ARD Regression  7047.282458  0.980022
# 1                 ElasticNet CV  7325.631274  0.979233
# 0             Linear Regression  7678.318327  0.978233
# 4                    Lasso Lars  8706.282003  0.975319
# 6  Passive Aggressive Regressor  9921.197144  0.971874

# %%
dfa1=pd.read_csv('/content/united-states-trade-gdp-ratio.csv', error_bad_lines=False)
dfa2=pd.read_csv('/content/united-states-population-2021-02-21.csv', error_bad_lines=False)
dfa3=pd.read_csv('/content/united-states-foreign-direct-investment.csv', error_bad_lines=False)
dfa4=pd.read_csv('/content/united-states-poverty-rate.csv', error_bad_lines=False)
dfa5=pd.read_csv('/content/united-states-exports.csv', error_bad_lines=False)
dfa6=pd.read_csv('/content/united-states-imports.csv', error_bad_lines=False)
dfa7=pd.read_csv('/content/united-states-tourism-statistics.csv', error_bad_lines=False)
dfa8=pd.read_csv('/content/united-states-unemployment-rate.csv', error_bad_lines=False)

# %%
dfa1['date']=pd.to_datetime(dfa1['date'])

# %%
dfa2['date']=pd.to_datetime(dfa2['date'])
dfa3['date']=pd.to_datetime(dfa3['date'])
dfa4['date']=pd.to_datetime(dfa4['date'])
dfa5['date']=pd.to_datetime(dfa5['date'])
dfa6['date']=pd.to_datetime(dfa6['date'])
dfa7['date']=pd.to_datetime(dfa7['date'])
dfa8['date']=pd.to_datetime(dfa8['date'])

# %%
dfa7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           24 non-null     datetime64[ns]
#  1    Spending ($)  24 non-null     int64
#  2    % of Exports  24 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 704.0 bytes

# %%
from functools import reduce
dfs2=[dfa1,dfa2,dfa3,dfa5,dfa6]
dfs1=[dfa1,dfa2,dfa3,dfa4,dfa5,dfa6,dfa7,dfa8]
df_final1 = reduce(lambda left,right: pd.merge(left,right,on='date'), dfs1)
df_final2 = reduce(lambda left,right: pd.merge(left,right,on='date'), dfs2)

# %%
df_final2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              50 non-null     datetime64[ns]
#  1   Trade (% of GDP)  50 non-null     float64
#  2    Population       50 non-null     int64
#  3    Inflows          50 non-null     float64
#  4   % of gdp          50 non-null     float64
#  5    Exports          50 non-null     float64
#  6    % of GDP         50 non-null     float64
#  7   Imports           50 non-null     float64
#  8   % of GDP          50 non-null     float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 3.9 KB

# %%
plt.figure(figsize=(20,15))
#ax=subplot(111)
sns.heatmap(df_final1.corr(),annot=True,cmap='coolwarm',linewidths=1.0)
plt.show()

# %%
plt.figure(figsize=(20,15))
#ax=subplot(111)
sns.heatmap(df_final2.corr(),annot=True,linewidths=1.0)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
df__=df_final
#X=df10.drop(['date','GDP Billions of US $','Per Capita US $','Births per 1000 People','Deaths per 1000 Live Births','Annual_Change_x','% of GDP',' % of GDP',' % of Exports','Unemployment Rate (%)'],axis=1)
X=df__.drop(['date','GDP Billions of US $','Per Capita US $','Births per 1000 People','Deaths per 1000 Live Births','% of GDP',' % of GDP'],axis=1)

Y=df_final['GDP Billions of US $']
